# %%
import sys
import os
PATH_CURRENT = '/home/jupyter'
PATH_MODEL = f'{PATH_CURRENT}/meme_hateful_detection/models'

# module_path = PATH_CURRENT
if PATH_CURRENT not in sys.path:
    sys.path.append(PATH_CURRENT)
if PATH_MODEL not in sys.path:
    sys.path.append(PATH_MODEL)

# %%
import pandas as pd
# import meme_hateful_detection.processors.processors
# import meme_hateful_detection.models.concat_vl

# %% [markdown]
# | Baseline         | Model Key      | Pretrained Key                                   | Baseine Config                                                     |
# |------------------|----------------|--------------------------------------------------|------------------------------------------------------------|
# | Image-Grid       | unimodal_image | unimodal_image.hateful_memes.images              | projects/hateful_memes/configs/unimodal/image.yaml         |
# | Image-Region     | unimodal_image | unimodal_image.hateful_memes.features            | projects/hateful_memes/configs/unimodal/with_features.yaml |
# | Text BERT        | unimodal_text  | unimodal_text.hateful_memes.bert                 | projects/hateful_memes/configs/unimodal/bert.yaml          |
# | Late Fusion      | late_fusion    | late_fusion.hateful_memes                        | projects/hateful_memes/configs/late_fusion/defaults.yaml   |
# | ConcatBERT       | concat_bert    | concat_bert.hateful_memes                        | projects/hateful_memes/configs/concat_bert/defaults.yaml   |
# | MMBT-Grid        | mmbt           | mmbt.hateful_memes.images                        | projects/hateful_memes/configs/mmbt/defaults.yaml          |
# | MMBT-Region      | mmbt           | mmbt.hateful_memes.features                      | projects/hateful_memes/configs/mmbt/with_features.yaml     |
# | ViLBERT          | vilbert        | vilbert.finetuned.hateful_memes.direct           | projects/hateful_memes/configs/vilbert/defaults.yaml       |
# | Visual BERT      | visual_bert    | visual_bert.finetuned.hateful_memes.direct       | projects/hateful_memes/configs/visual_bert/direct.yaml     |
# | ViLBERT CC       | vilbert        | vilbert.finetuned.hateful_memes.from_cc_original | projects/hateful_memes/configs/vilbert/from_cc.yaml        |
# | Visual BERT COCO | visual_bert    | visual_bert.finetuned.hateful_memes.from_coco    | projects/hateful_memes/configs/visual_bert/from_coco.yaml  |

# %%
df_model_config = pd.read_csv(f'{PATH_MODEL}/model_config.csv', sep = ';')
df_model_config.head()

# %%
import os
import sys
sys.argv = ['mmf_predict', 'config=/home/jupyter/meme_hateful_detection/configs/unimodal/image.yaml', 'model=unimodal_image', 'dataset=hateful_memes', 'run_type=test', 'checkpoint.resume_zoo=unimodal_image.hateful_memes.images']
str_exec = ' '.join(sys.argv)
# !{str_exec}
print(str_exec)
# !mmf_predict config=/home/jupyter/meme_hateful_detection/configs/unimodal/image.yaml model=unimodal_image dataset=hateful_memes run_type=test checkpoint.resume_zoo=unimodal_image.hateful_memes.images
# !mmf_predict config=/home/jupyter/meme_hateful_detection/configs/unimodal/image.yaml model=unimodal_image dataset=hateful_memes run_type=test checkpoint.resume_zoo=unimodal_image.hateful_memes.images

# %%
for index, row in df_model_config.iterrows():
    model_baseline = row['baseline']
    model_key = row['model_key']
    model_pretrained_key = row['pretrained_key']
    baseline_config = row['baseline_config']
    custom_config = row['custom_config']
    str_exec = f'mmf_predict config=../{baseline_config} model={model_key} dataset=hateful_memes run_type=test checkpoint.resume_zoo={model_pretrained_key}'
#     print(str_exec)
    # !{str_exec}
#     MMF_USER_DIR="." mmf_run config="configs/experiments/defaults.yaml"  model=concat_vl dataset=hateful_memes training.num_workers=0
# Out:
# Namespace(config_override=None, local_rank=None, opts=['config=../configs/unimodal/image.yaml', 'model=unimodal_image', 'dataset=hateful_memes', 'run_type=test', 'checkpoint.resume_zoo=unimodal_image.hateful_memes.images', 'evaluation.predict=true'])
# /home/jupyter/mmf/mmf/utils/configuration.py:527: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   "Device specified is 'cuda' but cuda is not present. "
# Overriding option config to ../configs/unimodal/image.yaml
# Overriding option model to unimodal_image
# Overriding option datasets to hateful_memes
# Overriding option run_type to test
# Overriding option checkpoint.resume_zoo to unimodal_image.hateful_memes.images
# Overriding option evaluation.predict to true
# Using seed 16942113
# Logging to: ./save/logs/train_2020-05-30T01:28:16.log
# 2020-05-30T01:28:16 INFO: Loading datasets
# 2020-05-30T01:28:28 INFO: Torch version is: 1.5.0
# 2020-05-30T01:28:28 INFO: Loading checkpoint
# 2020-05-30T01:28:32 WARNING: /home/jupyter/mmf/mmf/utils/checkpoint.py:224: UserWarning: 'optimizer' key is not present in the checkpoint asked to be loaded. Skipping.
#   "'optimizer' key is not present in the "
#
# 2020-05-30T01:28:32 INFO: Checkpoint loaded
# 2020-05-30T01:28:32 INFO: Starting test inference predictions
# 2020-05-30T01:28:32 INFO: Predicting for hateful_memes
# 100%|███████████████████████████████████████████| 32/32 [04:48<00:00,  9.00s/it]
# 2020-05-30T01:33:20 INFO: Wrote evalai predictions for hateful_memes to /home/jupyter/meme_hateful_detection/notebooks/save/hateful_memes_unimodal_image_16942113/reports/hateful_memes_run_test_2020-05-30T01:33:20.csv
# 2020-05-30T01:33:20 INFO: Finished predicting
# Namespace(config_override=None, local_rank=None, opts=['config=../configs/unimodal/with_features.yaml', 'model=unimodal_image', 'dataset=hateful_memes', 'run_type=test', 'checkpoint.resume_zoo=unimodal_image.hateful_memes.features', 'evaluation.predict=true'])
# /home/jupyter/mmf/mmf/utils/configuration.py:527: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   "Device specified is 'cuda' but cuda is not present. "
# /opt/conda/lib/python3.7/site-packages/omegaconf/dictconfig.py:252: UserWarning: Keys with dot (../../../others/unimodal/configs/hateful_memes/with_features.yaml) are deprecated and will have different semantic meaning the next major version of OmegaConf (2.1)
# See the compact keys issue for more details: https://github.com/omry/omegaconf/issues/152
# You can disable this warning by setting the environment variable OC_DISABLE_DOT_ACCESS_WARNING=1
#   warnings.warn(message=msg, category=UserWarning)
# Overriding option config to ../configs/unimodal/with_features.yaml
# Overriding option model to unimodal_image
# Overriding option datasets to hateful_memes
# Overriding option run_type to test
# Overriding option checkpoint.resume_zoo to unimodal_image.hateful_memes.features
# Overriding option evaluation.predict to true
# Using seed 23408258
# Logging to: ./save/logs/train_2020-05-30T01:33:23.log
# 2020-05-30T01:33:23 INFO: Loading datasets
# 2020-05-30T01:33:27 WARNING: /home/jupyter/mmf/mmf/models/base_model.py:97: UserWarning: No losses are defined in model configuration. You are expected to return loss in your return dict from forward.
#   "No losses are defined in model configuration. You are expected "
#
# Traceback (most recent call last):
#   File "/opt/conda/bin/mmf_predict", line 11, in <module>
#     load_entry_point('mmf', 'console_scripts', 'mmf_predict')()
#   File "/home/jupyter/mmf/mmf_cli/predict.py", line 11, in predict
#     run(predict=True)
#   File "/home/jupyter/mmf/mmf_cli/run.py", line 89, in run
#     main(configuration, predict=predict)
#   File "/home/jupyter/mmf/mmf_cli/run.py", line 36, in main
#     trainer.load()
#   File "/home/jupyter/mmf/mmf/trainers/base_trainer.py", line 61, in load
#     self.load_model_and_optimizer()
#   File "/home/jupyter/mmf/mmf/trainers/base_trainer.py", line 124, in load_model_and_optimizer
#     self.optimizer = build_optimizer(self.model, self.config)
#   File "/home/jupyter/mmf/mmf/utils/build.py", line 161, in build_optimizer
#     "Optimizer attributes must have a 'type' key "
# ValueError: Optimizer attributes must have a 'type' key specifying the type of optimizer. (Custom or PyTorch)
# Namespace(config_override=None, local_rank=None, opts=['config=../configs/unimodal/bert.yaml', 'model=unimodal_text', 'dataset=hateful_memes', 'run_type=test', 'checkpoint.resume_zoo=unimodal_text.hateful_memes.bert', 'evaluation.predict=true'])
# /home/jupyter/mmf/mmf/utils/configuration.py:527: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   "Device specified is 'cuda' but cuda is not present. "
# /opt/conda/lib/python3.7/site-packages/omegaconf/dictconfig.py:252: UserWarning: Keys with dot (../../../others/unimodal/configs/hateful_memes/bert.yaml) are deprecated and will have different semantic meaning the next major version of OmegaConf (2.1)
# See the compact keys issue for more details: https://github.com/omry/omegaconf/issues/152
# You can disable this warning by setting the environment variable OC_DISABLE_DOT_ACCESS_WARNING=1
#   warnings.warn(message=msg, category=UserWarning)
# Overriding option config to ../configs/unimodal/bert.yaml
# Overriding option model to unimodal_text
# Overriding option datasets to hateful_memes
# Overriding option run_type to test
# Overriding option checkpoint.resume_zoo to unimodal_text.hateful_memes.bert
# Overriding option evaluation.predict to true
# Using seed 30690247
# Logging to: ./save/logs/train_2020-05-30T01:33:30.log
# 2020-05-30T01:33:30 INFO: Loading datasets
# Traceback (most recent call last):
#   File "/opt/conda/bin/mmf_predict", line 11, in <module>
#     load_entry_point('mmf', 'console_scripts', 'mmf_predict')()
#   File "/home/jupyter/mmf/mmf_cli/predict.py", line 11, in predict
#     run(predict=True)
#   File "/home/jupyter/mmf/mmf_cli/run.py", line 89, in run
#     main(configuration, predict=predict)
#   File "/home/jupyter/mmf/mmf_cli/run.py", line 36, in main
#     trainer.load()
#   File "/home/jupyter/mmf/mmf/trainers/base_trainer.py", line 61, in load
#     self.load_model_and_optimizer()
#   File "/home/jupyter/mmf/mmf/trainers/base_trainer.py", line 113, in load_model_and_optimizer
#     self.model = build_model(attributes)
#   File "/home/jupyter/mmf/mmf/utils/build.py", line 41, in build_model
#     model.build()
#   File "/home/jupyter/mmf/mmf/models/unimodal.py", line 51, in build
#     self.base = UnimodalBase(self.config)
#   File "/home/jupyter/mmf/mmf/models/unimodal.py", line 15, in __init__
#     super().__init__(config, *args, **kwargs)
#   File "/home/jupyter/mmf/mmf/modules/encoders.py", line 208, in __init__
#     self.build()
#   File "/home/jupyter/mmf/mmf/models/unimodal.py", line 18, in build
#     encoders = self._build_encoders(self.config)
#   File "/home/jupyter/mmf/mmf/modules/encoders.py", line 227, in _build_encoders
#     text_encoder = build_text_encoder(config.text_encoder)
#   File "/home/jupyter/mmf/mmf/utils/build.py", line 216, in build_text_encoder
#     text_encoder = TextEncoder(config, *args, **kwargs)
#   File "/home/jupyter/mmf/mmf/modules/encoders.py", line 147, in __init__
#     self.module = TextEmbeddingEncoder(config.params)
#   File "/home/jupyter/mmf/mmf/modules/encoders.py", line 162, in __init__
#     self._embedding_params.type, **self._embedding_params.params
#   File "/home/jupyter/mmf/mmf/modules/embeddings.py", line 30, in __init__
#     self.module = VocabEmbedding(**kwargs)
#   File "/home/jupyter/mmf/mmf/modules/embeddings.py", line 58, in __init__
#     self.vocab = Vocab(**vocab_params)
#   File "/home/jupyter/mmf/mmf/utils/vocab.py", line 40, in __init__
#     self.vocab = IntersectedVocab(*args, **params)
#   File "/home/jupyter/mmf/mmf/utils/vocab.py", line 277, in __init__
#     super().__init__(vocab_file, *args, **kwargs)
#   File "/home/jupyter/mmf/mmf/utils/vocab.py", line 125, in __init__
#     raise RuntimeError("Vocab not found at " + vocab_file)
# RuntimeError: Vocab not found at /home/jupyter/.cache/torch/mmf/data/vocabs/vocabulary_100k.txt
# Namespace(config_override=None, local_rank=None, opts=['config=../configs/late_fusion/defaults.yaml', 'model=late_fusion', 'dataset=hateful_memes', 'run_type=test', 'checkpoint.resume_zoo=late_fusion.hateful_memes', 'evaluation.predict=true'])
# /home/jupyter/mmf/mmf/utils/configuration.py:527: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   "Device specified is 'cuda' but cuda is not present. "
# Traceback (most recent call last):
#   File "/opt/conda/bin/mmf_predict", line 11, in <module>
#     load_entry_point('mmf', 'console_scripts', 'mmf_predict')()
#   File "/home/jupyter/mmf/mmf_cli/predict.py", line 11, in predict
#     run(predict=True)
#   File "/home/jupyter/mmf/mmf_cli/run.py", line 58, in run
#     configuration = Configuration(args)
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 210, in __init__
#     other_configs = self._build_other_configs()
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 227, in _build_other_configs
#     user_config = self._build_user_config(opts_config)
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 253, in _build_user_config
#     user_config = load_yaml(self.config_path)
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 30, in load_yaml
#     raise e
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 23, in load_yaml
#     mapping = OmegaConf.load(abs_f)
#   File "/opt/conda/lib/python3.7/site-packages/omegaconf/omegaconf.py", line 246, in load
#     with io.open(os.path.abspath(file_), "r", encoding="utf-8") as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jupyter/meme_hateful_detection/configs/late_fusion/defaults.yaml'
# Namespace(config_override=None, local_rank=None, opts=['config=../configs/concat_bert/defaults.yaml', 'model=concat_bert', 'dataset=hateful_memes', 'run_type=test', 'checkpoint.resume_zoo=concat_bert.hateful_memes', 'evaluation.predict=true'])
# /home/jupyter/mmf/mmf/utils/configuration.py:527: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   "Device specified is 'cuda' but cuda is not present. "
# /opt/conda/lib/python3.7/site-packages/omegaconf/dictconfig.py:252: UserWarning: Keys with dot (../../../others/concat_bert/hateful_memes/defaults.yaml) are deprecated and will have different semantic meaning the next major version of OmegaConf (2.1)
# See the compact keys issue for more details: https://github.com/omry/omegaconf/issues/152
# You can disable this warning by setting the environment variable OC_DISABLE_DOT_ACCESS_WARNING=1
#   warnings.warn(message=msg, category=UserWarning)
# Overriding option config to ../configs/concat_bert/defaults.yaml
# Overriding option model to concat_bert
# Overriding option datasets to hateful_memes
# Overriding option run_type to test
# Overriding option checkpoint.resume_zoo to concat_bert.hateful_memes
# Overriding option evaluation.predict to true
# Using seed 38555347
# Logging to: ./save/logs/train_2020-05-30T01:33:38.log
# 2020-05-30T01:33:38 INFO: Loading datasets
# 2020-05-30T01:33:49 WARNING: /home/jupyter/mmf/mmf/models/base_model.py:97: UserWarning: No losses are defined in model configuration. You are expected to return loss in your return dict from forward.
#   "No losses are defined in model configuration. You are expected "
#
# Traceback (most recent call last):
#   File "/opt/conda/bin/mmf_predict", line 11, in <module>
#     load_entry_point('mmf', 'console_scripts', 'mmf_predict')()
#   File "/home/jupyter/mmf/mmf_cli/predict.py", line 11, in predict
#     run(predict=True)
#   File "/home/jupyter/mmf/mmf_cli/run.py", line 89, in run
#     main(configuration, predict=predict)
#   File "/home/jupyter/mmf/mmf_cli/run.py", line 36, in main
#     trainer.load()
#   File "/home/jupyter/mmf/mmf/trainers/base_trainer.py", line 61, in load
#     self.load_model_and_optimizer()
#   File "/home/jupyter/mmf/mmf/trainers/base_trainer.py", line 124, in load_model_and_optimizer
#     self.optimizer = build_optimizer(self.model, self.config)
#   File "/home/jupyter/mmf/mmf/utils/build.py", line 161, in build_optimizer
#     "Optimizer attributes must have a 'type' key "
# ValueError: Optimizer attributes must have a 'type' key specifying the type of optimizer. (Custom or PyTorch)
# Namespace(config_override=None, local_rank=None, opts=['config=../configs/mmbt/defaults.yaml', 'model=mmbt', 'dataset=hateful_memes', 'run_type=test', 'checkpoint.resume_zoo=mmbt.hateful_memes.images', 'evaluation.predict=true'])
# /home/jupyter/mmf/mmf/utils/configuration.py:527: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   "Device specified is 'cuda' but cuda is not present. "
# Traceback (most recent call last):
#   File "/opt/conda/bin/mmf_predict", line 11, in <module>
#     load_entry_point('mmf', 'console_scripts', 'mmf_predict')()
#   File "/home/jupyter/mmf/mmf_cli/predict.py", line 11, in predict
#     run(predict=True)
#   File "/home/jupyter/mmf/mmf_cli/run.py", line 58, in run
#     configuration = Configuration(args)
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 210, in __init__
#     other_configs = self._build_other_configs()
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 227, in _build_other_configs
#     user_config = self._build_user_config(opts_config)
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 253, in _build_user_config
#     user_config = load_yaml(self.config_path)
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 30, in load_yaml
#     raise e
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 23, in load_yaml
#     mapping = OmegaConf.load(abs_f)
#   File "/opt/conda/lib/python3.7/site-packages/omegaconf/omegaconf.py", line 246, in load
#     with io.open(os.path.abspath(file_), "r", encoding="utf-8") as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jupyter/meme_hateful_detection/configs/mmbt/defaults.yaml'
# Namespace(config_override=None, local_rank=None, opts=['config=../configs/mmbt/with_features.yaml', 'model=mmbt', 'dataset=hateful_memes', 'run_type=test', 'checkpoint.resume_zoo=mmbt.hateful_memes.features', 'evaluation.predict=true'])
# /home/jupyter/mmf/mmf/utils/configuration.py:527: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   "Device specified is 'cuda' but cuda is not present. "
# Traceback (most recent call last):
#   File "/opt/conda/bin/mmf_predict", line 11, in <module>
#     load_entry_point('mmf', 'console_scripts', 'mmf_predict')()
#   File "/home/jupyter/mmf/mmf_cli/predict.py", line 11, in predict
#     run(predict=True)
#   File "/home/jupyter/mmf/mmf_cli/run.py", line 58, in run
#     configuration = Configuration(args)
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 210, in __init__
#     other_configs = self._build_other_configs()
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 227, in _build_other_configs
#     user_config = self._build_user_config(opts_config)
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 253, in _build_user_config
#     user_config = load_yaml(self.config_path)
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 30, in load_yaml
#     raise e
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 23, in load_yaml
#     mapping = OmegaConf.load(abs_f)
#   File "/opt/conda/lib/python3.7/site-packages/omegaconf/omegaconf.py", line 246, in load
#     with io.open(os.path.abspath(file_), "r", encoding="utf-8") as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jupyter/meme_hateful_detection/configs/mmbt/with_features.yaml'
# Namespace(config_override=None, local_rank=None, opts=['config=../configs/vilbert/defaults.yaml', 'model=vilbert', 'dataset=hateful_memes', 'run_type=test', 'checkpoint.resume_zoo=vilbert.finetuned.hateful_memes.direct', 'evaluation.predict=true'])
# /home/jupyter/mmf/mmf/utils/configuration.py:527: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   "Device specified is 'cuda' but cuda is not present. "
# Traceback (most recent call last):
#   File "/opt/conda/bin/mmf_predict", line 11, in <module>
#     load_entry_point('mmf', 'console_scripts', 'mmf_predict')()
#   File "/home/jupyter/mmf/mmf_cli/predict.py", line 11, in predict
#     run(predict=True)
#   File "/home/jupyter/mmf/mmf_cli/run.py", line 58, in run
#     configuration = Configuration(args)
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 210, in __init__
#     other_configs = self._build_other_configs()
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 227, in _build_other_configs
#     user_config = self._build_user_config(opts_config)
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 253, in _build_user_config
#     user_config = load_yaml(self.config_path)
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 30, in load_yaml
#     raise e
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 23, in load_yaml
#     mapping = OmegaConf.load(abs_f)
#   File "/opt/conda/lib/python3.7/site-packages/omegaconf/omegaconf.py", line 246, in load
#     with io.open(os.path.abspath(file_), "r", encoding="utf-8") as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jupyter/meme_hateful_detection/configs/vilbert/defaults.yaml'
# Namespace(config_override=None, local_rank=None, opts=['config=../configs/visual_bert/direct.yaml', 'model=visual_bert', 'dataset=hateful_memes', 'run_type=test', 'checkpoint.resume_zoo=visual_bert.finetuned.hateful_memes.direct', 'evaluation.predict=true'])
# /home/jupyter/mmf/mmf/utils/configuration.py:527: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   "Device specified is 'cuda' but cuda is not present. "
# Traceback (most recent call last):
#   File "/opt/conda/bin/mmf_predict", line 11, in <module>
#     load_entry_point('mmf', 'console_scripts', 'mmf_predict')()
#   File "/home/jupyter/mmf/mmf_cli/predict.py", line 11, in predict
#     run(predict=True)
#   File "/home/jupyter/mmf/mmf_cli/run.py", line 58, in run
#     configuration = Configuration(args)
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 210, in __init__
#     other_configs = self._build_other_configs()
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 227, in _build_other_configs
#     user_config = self._build_user_config(opts_config)
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 253, in _build_user_config
#     user_config = load_yaml(self.config_path)
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 30, in load_yaml
#     raise e
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 23, in load_yaml
#     mapping = OmegaConf.load(abs_f)
#   File "/opt/conda/lib/python3.7/site-packages/omegaconf/omegaconf.py", line 246, in load
#     with io.open(os.path.abspath(file_), "r", encoding="utf-8") as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jupyter/meme_hateful_detection/configs/visual_bert/direct.yaml'
# Namespace(config_override=None, local_rank=None, opts=['config=../configs/vilbert/from_cc.yaml', 'model=vilbert', 'dataset=hateful_memes', 'run_type=test', 'checkpoint.resume_zoo=vilbert.finetuned.hateful_memes.from_cc_original', 'evaluation.predict=true'])
# /home/jupyter/mmf/mmf/utils/configuration.py:527: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   "Device specified is 'cuda' but cuda is not present. "
# Traceback (most recent call last):
#   File "/opt/conda/bin/mmf_predict", line 11, in <module>
#     load_entry_point('mmf', 'console_scripts', 'mmf_predict')()
#   File "/home/jupyter/mmf/mmf_cli/predict.py", line 11, in predict
#     run(predict=True)
#   File "/home/jupyter/mmf/mmf_cli/run.py", line 58, in run
#     configuration = Configuration(args)
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 210, in __init__
#     other_configs = self._build_other_configs()
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 227, in _build_other_configs
#     user_config = self._build_user_config(opts_config)
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 253, in _build_user_config
#     user_config = load_yaml(self.config_path)
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 30, in load_yaml
#     raise e
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 23, in load_yaml
#     mapping = OmegaConf.load(abs_f)
#   File "/opt/conda/lib/python3.7/site-packages/omegaconf/omegaconf.py", line 246, in load
#     with io.open(os.path.abspath(file_), "r", encoding="utf-8") as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jupyter/meme_hateful_detection/configs/vilbert/from_cc.yaml'
# Namespace(config_override=None, local_rank=None, opts=['config=../configs/visual_bert/from_coco.yaml', 'model=visual_bert', 'dataset=hateful_memes', 'run_type=test', 'checkpoint.resume_zoo=visual_bert.finetuned.hateful_memes.from_coco', 'evaluation.predict=true'])
# /home/jupyter/mmf/mmf/utils/configuration.py:527: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   "Device specified is 'cuda' but cuda is not present. "
# Traceback (most recent call last):
#   File "/opt/conda/bin/mmf_predict", line 11, in <module>
#     load_entry_point('mmf', 'console_scripts', 'mmf_predict')()
#   File "/home/jupyter/mmf/mmf_cli/predict.py", line 11, in predict
#     run(predict=True)
#   File "/home/jupyter/mmf/mmf_cli/run.py", line 58, in run
#     configuration = Configuration(args)
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 210, in __init__
#     other_configs = self._build_other_configs()
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 227, in _build_other_configs
#     user_config = self._build_user_config(opts_config)
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 253, in _build_user_config
#     user_config = load_yaml(self.config_path)
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 30, in load_yaml
#     raise e
#   File "/home/jupyter/mmf/mmf/utils/configuration.py", line 23, in load_yaml
#     mapping = OmegaConf.load(abs_f)
#   File "/opt/conda/lib/python3.7/site-packages/omegaconf/omegaconf.py", line 246, in load
#     with io.open(os.path.abspath(file_), "r", encoding="utf-8") as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jupyter/meme_hateful_detection/configs/visual_bert/from_coco.yaml'

# %%
# !MMF_USER_DIR=".." mmf_run config="/home/jupyter/meme_hateful_detection/configs/unimodal/image.yaml" model=unimodal_image dataset=hateful_memes training.num_workers=0
# meme_hateful_detection/configs/unimodal/image.yaml
# !mmf_run config=projects/hateful_memes/configs/unimodal/image.yaml       model=unimodal_image dataset=hateful_memes

# %%
from mmf.common.registry import registry

model_cls = registry.get_model_class("unimodal_image")
model = model_cls.from_pretrained("unimodal_image.hateful_memes.images")

# %%
type(model)

# %%
# Training
# !mmf_run config=projects/hateful_memes/configs/unimodal/image.yaml model=unimodal_image dataset=hateful_memes

# %%
# Evaluation
# !mmf_run config=projects/hateful_memes/configs/unimodal/image.yaml model=unimodal_image dataset=hateful_memes run_type=val

# %%
# Predictions
#Val
# !mmf_predict config=projects/hateful_memes/configs/unimodal/image.yaml model=unimodal_image dataset=hateful_memes run_type=val

#Test
# !mmf_predict config=projects/hateful_memes/configs/mmbt/defaults.yaml model=mmbt dataset=hateful_memes run_type=test

# %%
# Evaluating Pretrained Models
# Validation set, use the following command:
# mmf_run config=projects/hateful_memes/configs/unimodal/image.yaml model=unimodal_image dataset=hateful_memes run_type=val checkpoint.resume_zoo=<REPLACE_WITH_PRETRAINED_ZOO_KEY>
# !mmf_run config=projects/hateful_memes/configs/unimodal/image.yaml model=unimodal_image dataset=hateful_memes run_type=val checkpoint.resume_zoo=unimodal_image.hateful_memes.images

# To generate predictions using pretrained models, use the following command:
    
# !mmf_predict config=/home/jupyter/meme_hateful_detection/configs/unimodal/image.yaml model=unimodal_image dataset=hateful_memes run_type=test checkpoint.resume_zoo=unimodal_image.hateful_memes.images
# mmf_predict config=projects/hateful_memes/configs/unimodal/image.yaml model=unimodal_image dataset=hateful_memes run_type=test checkpoint.resume_zoo=<R

# %%
os.system('ls -l')

# %%
# os.system(str_exec)

# myCmd = os.popen(str_exec).read()
# print(myCmd)

# %%
from mmf.common.registry import registry


import torch
import torch.nn as nn
from torch.autograd import Variable

# # Defining Model
# class LinearRegressor(nn.Module):
#     def __init__(self, inp_size, require_bias=True):
#         super(LinearRegressor, self).__init__()
#         self.linear = nn.Linear(in_features=inp_size, out_features=1, bias=require_bias)
    
#     def forward(self, inp_batch):
#         return self.linear(inp_batch)
    
# Creating sample data for sum of 3 elements
X = []
for i in range(2):
    for j in range(2):
        for k in range(2):
            X.append([i, j, k])

y = map(lambda x: x[0] + x[1] + x[2], X)
X = Variable(torch.FloatTensor(X), requires_grad=False)
y = Variable(torch.FloatTensor(y), requires_grad=False)

# Creating model and defining loss function and optimizer
model_cls = registry.get_model_class("unimodal_image")
model = model_cls.from_pretrained("unimodal_image.hateful_memes.images")
loss_fn = nn.MSELoss()
optim = torch.optim.Adam(model.parameters())

# Training the model
for epoch in range(2):
    optim.zero_grad()
    
    out = model(X)
    loss = loss_fn(out, y)
    
    loss.backward()
    optim.step()

# %%
import torch
import pycuda.driver as cuda
cuda.init()
# from __future__ import print_function
# import torch
# x = torch.rand(5, 3)
# print(x)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-34b2993cf8e7> in <module>
#       1 import torch
# ----> 2 import pycuda.driver as cuda
#       3 cuda.init()
#       4 # from __future__ import print_function
#       5 # import torch
#
# ModuleNotFoundError: No module named 'pycuda'

# %%
import torch
torch.cuda.is_available()
# Out:
# False

# %%
import torch
print(torch.__version__)
# torch.zeros(1).cuda()
# Out:
# 1.5.0
