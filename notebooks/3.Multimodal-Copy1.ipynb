# %%
import sys
import os
import pandas as pd

PATH_CURRENT = '/home/jupyter'
PATH_MODEL = f'{PATH_CURRENT}/meme_hateful_detection/models'

# module_path = PATH_CURRENT
if PATH_CURRENT not in sys.path:
    sys.path.append(PATH_CURRENT)
if PATH_MODEL not in sys.path:
    sys.path.append(PATH_MODEL)

# %% [markdown]
# | Baseline         | Model Key      | Pretrained Key                                   | Baseine Config                                                     |
# |------------------|----------------|--------------------------------------------------|------------------------------------------------------------|
# | Image-Grid       | unimodal_image | unimodal_image.hateful_memes.images              | projects/hateful_memes/configs/unimodal/image.yaml         |
# | Image-Region     | unimodal_image | unimodal_image.hateful_memes.features            | projects/hateful_memes/configs/unimodal/with_features.yaml |
# | Text BERT        | unimodal_text  | unimodal_text.hateful_memes.bert                 | projects/hateful_memes/configs/unimodal/bert.yaml          |
# | Late Fusion      | late_fusion    | late_fusion.hateful_memes                        | projects/hateful_memes/configs/late_fusion/defaults.yaml   |
# | ConcatBERT       | concat_bert    | concat_bert.hateful_memes                        | projects/hateful_memes/configs/concat_bert/defaults.yaml   |
# | MMBT-Grid        | mmbt           | mmbt.hateful_memes.images                        | projects/hateful_memes/configs/mmbt/defaults.yaml          |
# | MMBT-Region      | mmbt           | mmbt.hateful_memes.features                      | projects/hateful_memes/configs/mmbt/with_features.yaml     |
# | ViLBERT          | vilbert        | vilbert.finetuned.hateful_memes.direct           | projects/hateful_memes/configs/vilbert/defaults.yaml       |
# | Visual BERT      | visual_bert    | visual_bert.finetuned.hateful_memes.direct       | projects/hateful_memes/configs/visual_bert/direct.yaml     |
# | ViLBERT CC       | vilbert        | vilbert.finetuned.hateful_memes.from_cc_original | projects/hateful_memes/configs/vilbert/from_cc.yaml        |
# | Visual BERT COCO | visual_bert    | visual_bert.finetuned.hateful_memes.from_coco    | projects/hateful_memes/configs/visual_bert/from_coco.yaml  |

# %%
df_model_config = pd.read_csv(f'{PATH_MODEL}/model_config.csv', sep = ';')
df_model_config.head(11)
# Out:
#             baseline       model_key  \
# 0         Image-Grid  unimodal_image
# 1       Image-Region  unimodal_image
# 2          Text BERT   unimodal_text
# 3        Late Fusion     late_fusion
# 4         ConcatBERT     concat_bert
# 5          MMBT-Grid            mmbt
# 6        MMBT-Region            mmbt
# 7            ViLBERT         vilbert
# 8        Visual BERT     visual_bert
# 9         ViLBERT CC         vilbert
# 10  Visual BERT COCO     visual_bert
#
#                                       pretrained_key  \
# 0                unimodal_image.hateful_memes.images
# 1              unimodal_image.hateful_memes.features
# 2                   unimodal_text.hateful_memes.bert
# 3                          late_fusion.hateful_memes
# 4                          concat_bert.hateful_memes
# 5                          mmbt.hateful_memes.images
# 6                        mmbt.hateful_memes.features
# 7             vilbert.finetuned.hateful_memes.direct
# 8         visual_bert.finetuned.hateful_memes.direct
# 9   vilbert.finetuned.hateful_memes.from_cc_original
# 10     visual_bert.finetuned.hateful_memes.from_coco
#
#                         baseline_config  custom_config
# 0           configs/unimodal/image.yaml            NaN
# 1   configs/unimodal/with_features.yaml            NaN
# 2            configs/unimodal/bert.yaml            NaN
# 3     configs/late_fusion/defaults.yaml            NaN
# 4     configs/concat_bert/defaults.yaml            NaN
# 5            configs/mmbt/defaults.yaml            NaN
# 6       configs/mmbt/with_features.yaml            NaN
# 7         configs/vilbert/defaults.yaml            NaN
# 8       configs/visual_bert/direct.yaml            NaN
# 9          configs/vilbert/from_cc.yaml            NaN
# 10   configs/visual_bert/from_coco.yaml            NaN

# %%
for index, row in df_model_config.iterrows():
    model_baseline = row['baseline']
    model_key = row['model_key']
    model_pretrained_key = row['pretrained_key']
    baseline_config = row['baseline_config']
    custom_config = row['custom_config']
    str_exec = f'MMF_USER_DIR=".." mmf_predict config={baseline_config} model={model_key} dataset=hateful_memes run_type=test checkpoint.resume_zoo={model_pretrained_key}'
#     print(str_exec)
#     MMF_USER_DIR="." mmf_run config="configs/experiments/defaults.yaml"  model=concat_vl dataset=hateful_memes training.num_workers=0
    # !{str_exec}
# Out:
# Namespace(config_override=None, local_rank=None, opts=['config=configs/unimodal/image.yaml', 'model=unimodal_image', 'dataset=hateful_memes', 'run_type=test', 'checkpoint.resume_zoo=unimodal_image.hateful_memes.images', 'evaluation.predict=true'])
# /home/jupyter/mmf/mmf/utils/configuration.py:527: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   "Device specified is 'cuda' but cuda is not present. "
# Importing user_dir from /home/jupyter/meme_hateful_detection
# Overriding option config to configs/unimodal/image.yaml
# Overriding option model to unimodal_image
# Overriding option datasets to hateful_memes
# Overriding option run_type to test
# Overriding option checkpoint.resume_zoo to unimodal_image.hateful_memes.images
# Overriding option evaluation.predict to true
# Using seed 34653156
# Logging to: ./save/logs/train_2020-05-30T01:51:34.log
# 2020-05-30T01:51:34 INFO: Loading datasets
# 2020-05-30T01:51:38 INFO: Torch version is: 1.5.0
# 2020-05-30T01:51:38 INFO: Loading checkpoint
# 2020-05-30T01:51:40 WARNING: /home/jupyter/mmf/mmf/utils/checkpoint.py:224: UserWarning: 'optimizer' key is not present in the checkpoint asked to be loaded. Skipping.
#   "'optimizer' key is not present in the "
#
# 2020-05-30T01:51:40 INFO: Checkpoint loaded
# 2020-05-30T01:51:40 INFO: Starting test inference predictions
# 2020-05-30T01:51:40 INFO: Predicting for hateful_memes
# 100%|███████████████████████████████████████████| 32/32 [04:37<00:00,  8.66s/it]
# 2020-05-30T01:56:17 INFO: Wrote evalai predictions for hateful_memes to /home/jupyter/meme_hateful_detection/notebooks/save/hateful_memes_unimodal_image_34653156/reports/hateful_memes_run_test_2020-05-30T01:56:17.csv
# 2020-05-30T01:56:17 INFO: Finished predicting
# Namespace(config_override=None, local_rank=None, opts=['config=configs/unimodal/with_features.yaml', 'model=unimodal_image', 'dataset=hateful_memes', 'run_type=test', 'checkpoint.resume_zoo=unimodal_image.hateful_memes.features', 'evaluation.predict=true'])
# /home/jupyter/mmf/mmf/utils/configuration.py:527: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   "Device specified is 'cuda' but cuda is not present. "
# Importing user_dir from /home/jupyter/meme_hateful_detection
# Overriding option config to configs/unimodal/with_features.yaml
# Overriding option model to unimodal_image
# Overriding option datasets to hateful_memes
# Overriding option run_type to test
# Overriding option checkpoint.resume_zoo to unimodal_image.hateful_memes.features
# Overriding option evaluation.predict to true
# Using seed 20396428
# Logging to: ./save/logs/train_2020-05-30T01:56:20.log
# 2020-05-30T01:56:20 INFO: Loading datasets
# [ Downloading: https://dl.fbaipublicfiles.com/mmf/data/datasets/hateful_memes/defaults/features/features.tar.gz to /home/jupyter/.cache/torch/mmf/data/datasets/hateful_memes/defaults/features/features.tar.gz ]
# Downloading features.tar.gz: 100%|█████████| 8.44G/8.44G [02:09<00:00, 65.0MB/s]
# [ Starting checksum for features.tar.gz]
# [ Checksum successful for features.tar.gz]
# Unpacking features.tar.gz
# [ Downloading: https://dl.fbaipublicfiles.com/mmf/data/models/detectron/vmb_weights.tar.gz to /home/jupyter/.cache/torch/mmf/data/models/detectron.defaults/vmb_weights.tar.gz ]
# Downloading vmb_weights.tar.gz: 100%|██████| 15.5M/15.5M [00:01<00:00, 12.8MB/s]
# [ Starting checksum for vmb_weights.tar.gz]
# [ Checksum successful for vmb_weights.tar.gz]
# Unpacking vmb_weights.tar.gz
# 2020-05-30T02:02:57 INFO: Torch version is: 1.5.0
# 2020-05-30T02:02:57 INFO: Loading checkpoint
# [ Downloading: https://dl.fbaipublicfiles.com/mmf/data/models/unimodal_image/unimodal_image.finetuned.hateful_memes_features.tar.gz to /home/jupyter/.cache/torch/mmf/data/models/unimodal_image.hateful_memes.features/unimodal_image.finetuned.hateful_memes_features.tar.gz ]
# Downloading unimodal_image.finetuned.hateful_memes_features.tar.gz: 100%|█| 23.5
# [ Starting checksum for unimodal_image.finetuned.hateful_memes_features.tar.gz]
# [ Checksum successful for unimodal_image.finetuned.hateful_memes_features.tar.gz]
# Unpacking unimodal_image.finetuned.hateful_memes_features.tar.gz
# 2020-05-30T02:03:00 WARNING: /home/jupyter/mmf/mmf/utils/checkpoint.py:224: UserWarning: 'optimizer' key is not present in the checkpoint asked to be loaded. Skipping.
#   "'optimizer' key is not present in the "
#
# 2020-05-30T02:03:00 INFO: Checkpoint loaded
# 2020-05-30T02:03:00 INFO: Starting test inference predictions
# 2020-05-30T02:03:00 INFO: Predicting for hateful_memes
# 100%|███████████████████████████████████████████| 32/32 [01:09<00:00,  2.17s/it]
# 2020-05-30T02:04:09 INFO: Wrote evalai predictions for hateful_memes to /home/jupyter/meme_hateful_detection/notebooks/save/hateful_memes_unimodal_image_20396428/reports/hateful_memes_run_test_2020-05-30T02:04:09.csv
# 2020-05-30T02:04:09 INFO: Finished predicting
# Namespace(config_override=None, local_rank=None, opts=['config=configs/unimodal/bert.yaml', 'model=unimodal_text', 'dataset=hateful_memes', 'run_type=test', 'checkpoint.resume_zoo=unimodal_text.hateful_memes.bert', 'evaluation.predict=true'])
# /home/jupyter/mmf/mmf/utils/configuration.py:527: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   "Device specified is 'cuda' but cuda is not present. "
# Importing user_dir from /home/jupyter/meme_hateful_detection
# Overriding option config to configs/unimodal/bert.yaml
# Overriding option model to unimodal_text
# Overriding option datasets to hateful_memes
# Overriding option run_type to test
# Overriding option checkpoint.resume_zoo to unimodal_text.hateful_memes.bert
# Overriding option evaluation.predict to true
# Using seed 20696298
# Logging to: ./save/logs/train_2020-05-30T02:04:20.log
# 2020-05-30T02:04:20 INFO: Loading datasets
# 2020-05-30T02:04:28 INFO: Torch version is: 1.5.0
# 2020-05-30T02:04:28 INFO: Loading checkpoint
# [ Downloading: https://dl.fbaipublicfiles.com/mmf/data/models/unimodal_text/unimodal_text.finetuned.hateful_memes_bert.tar.gz to /home/jupyter/.cache/torch/mmf/data/models/unimodal_text.hateful_memes.bert/unimodal_text.finetuned.hateful_memes_bert.tar.gz ]
# Downloading unimodal_text.finetuned.hateful_memes_bert.tar.gz: 100%|█| 410M/410M
# [ Starting checksum for unimodal_text.finetuned.hateful_memes_bert.tar.gz]
# [ Checksum successful for unimodal_text.finetuned.hateful_memes_bert.tar.gz]
# Unpacking unimodal_text.finetuned.hateful_memes_bert.tar.gz
# 2020-05-30T02:04:47 WARNING: /home/jupyter/mmf/mmf/utils/checkpoint.py:224: UserWarning: 'optimizer' key is not present in the checkpoint asked to be loaded. Skipping.
#   "'optimizer' key is not present in the "
#
# 2020-05-30T02:04:47 INFO: Checkpoint loaded
# 2020-05-30T02:04:47 INFO: Starting test inference predictions
# 2020-05-30T02:04:47 INFO: Predicting for hateful_memes
# 100%|█████████████████████████████████████████████| 8/8 [04:34<00:00, 34.36s/it]
# 2020-05-30T02:09:22 INFO: Wrote evalai predictions for hateful_memes to /home/jupyter/meme_hateful_detection/notebooks/save/hateful_memes_unimodal_text_20696298/reports/hateful_memes_run_test_2020-05-30T02:09:22.csv
# 2020-05-30T02:09:22 INFO: Finished predicting
# Namespace(config_override=None, local_rank=None, opts=['config=configs/late_fusion/defaults.yaml', 'model=late_fusion', 'dataset=hateful_memes', 'run_type=test', 'checkpoint.resume_zoo=late_fusion.hateful_memes', 'evaluation.predict=true'])
# /home/jupyter/mmf/mmf/utils/configuration.py:527: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   "Device specified is 'cuda' but cuda is not present. "
# Importing user_dir from /home/jupyter/meme_hateful_detection
# Overriding option config to configs/late_fusion/defaults.yaml
# Overriding option model to late_fusion
# Overriding option datasets to hateful_memes
# Overriding option run_type to test
# Overriding option checkpoint.resume_zoo to late_fusion.hateful_memes
# Overriding option evaluation.predict to true
# Using seed 25995716
# Logging to: ./save/logs/train_2020-05-30T02:09:26.log
# 2020-05-30T02:09:26 INFO: Loading datasets
# 2020-05-30T02:09:34 INFO: Torch version is: 1.5.0
# 2020-05-30T02:09:34 INFO: Loading checkpoint
# [ Downloading: https://dl.fbaipublicfiles.com/mmf/data/models/late_fusion/late_fusion.finetuned.hateful_memes.tar.gz to /home/jupyter/.cache/torch/mmf/data/models/late_fusion.hateful_memes/late_fusion.finetuned.hateful_memes.tar.gz ]
# Downloading late_fusion.finetuned.hateful_memes.tar.gz: 100%|█| 635M/635M [00:09
# [ Starting checksum for late_fusion.finetuned.hateful_memes.tar.gz]
# [ Checksum successful for late_fusion.finetuned.hateful_memes.tar.gz]
# Unpacking late_fusion.finetuned.hateful_memes.tar.gz
# 2020-05-30T02:09:55 WARNING: /home/jupyter/mmf/mmf/utils/checkpoint.py:224: UserWarning: 'optimizer' key is not present in the checkpoint asked to be loaded. Skipping.
#   "'optimizer' key is not present in the "
#
# 2020-05-30T02:09:55 INFO: Checkpoint loaded
# 2020-05-30T02:09:55 INFO: Starting test inference predictions
# 2020-05-30T02:09:55 INFO: Predicting for hateful_memes
# 100%|███████████████████████████████████████████| 16/16 [09:01<00:00, 33.83s/it]
# 2020-05-30T02:18:56 INFO: Wrote evalai predictions for hateful_memes to /home/jupyter/meme_hateful_detection/notebooks/save/hateful_memes_late_fusion_25995716/reports/hateful_memes_run_test_2020-05-30T02:18:56.csv
# 2020-05-30T02:18:56 INFO: Finished predicting
# Namespace(config_override=None, local_rank=None, opts=['config=configs/concat_bert/defaults.yaml', 'model=concat_bert', 'dataset=hateful_memes', 'run_type=test', 'checkpoint.resume_zoo=concat_bert.hateful_memes', 'evaluation.predict=true'])
# /home/jupyter/mmf/mmf/utils/configuration.py:527: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   "Device specified is 'cuda' but cuda is not present. "
# Importing user_dir from /home/jupyter/meme_hateful_detection
# Overriding option config to configs/concat_bert/defaults.yaml
# Overriding option model to concat_bert
# Overriding option datasets to hateful_memes
# Overriding option run_type to test
# Overriding option checkpoint.resume_zoo to concat_bert.hateful_memes
# Overriding option evaluation.predict to true
# Using seed 59793761
# Logging to: ./save/logs/train_2020-05-30T02:18:59.log
# 2020-05-30T02:18:59 INFO: Loading datasets
# 2020-05-30T02:19:05 INFO: Torch version is: 1.5.0
# 2020-05-30T02:19:05 INFO: Loading checkpoint
# [ Downloading: https://dl.fbaipublicfiles.com/mmf/data/models/concat_bert/concat_bert.finetuned.hateful_memes.tar.gz to /home/jupyter/.cache/torch/mmf/data/models/concat_bert.hateful_memes/concat_bert.finetuned.hateful_memes.tar.gz ]
# Downloading concat_bert.finetuned.hateful_memes.tar.gz: 100%|█| 633M/633M [00:10
# [ Starting checksum for concat_bert.finetuned.hateful_memes.tar.gz]
# [ Checksum successful for concat_bert.finetuned.hateful_memes.tar.gz]
# Unpacking concat_bert.finetuned.hateful_memes.tar.gz
# 2020-05-30T02:19:27 WARNING: /home/jupyter/mmf/mmf/utils/checkpoint.py:224: UserWarning: 'optimizer' key is not present in the checkpoint asked to be loaded. Skipping.
#   "'optimizer' key is not present in the "
#
# 2020-05-30T02:19:27 INFO: Checkpoint loaded
# 2020-05-30T02:19:27 INFO: Starting test inference predictions
# 2020-05-30T02:19:27 INFO: Predicting for hateful_memes
# 100%|███████████████████████████████████████████| 16/16 [08:56<00:00, 33.54s/it]
# 2020-05-30T02:28:23 INFO: Wrote evalai predictions for hateful_memes to /home/jupyter/meme_hateful_detection/notebooks/save/hateful_memes_concat_bert_59793761/reports/hateful_memes_run_test_2020-05-30T02:28:23.csv
# 2020-05-30T02:28:23 INFO: Finished predicting
# Namespace(config_override=None, local_rank=None, opts=['config=configs/mmbt/defaults.yaml', 'model=mmbt', 'dataset=hateful_memes', 'run_type=test', 'checkpoint.resume_zoo=mmbt.hateful_memes.images', 'evaluation.predict=true'])
# /home/jupyter/mmf/mmf/utils/configuration.py:527: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   "Device specified is 'cuda' but cuda is not present. "
# Importing user_dir from /home/jupyter/meme_hateful_detection
# Overriding option config to configs/mmbt/defaults.yaml
# Overriding option model to mmbt
# Overriding option datasets to hateful_memes
# Overriding option run_type to test
# Overriding option checkpoint.resume_zoo to mmbt.hateful_memes.images
# Overriding option evaluation.predict to true
# Using seed 27132630
# Logging to: ./save/logs/train_2020-05-30T02:28:27.log
# 2020-05-30T02:28:27 INFO: Loading datasets
# 2020-05-30T02:28:33 INFO: Torch version is: 1.5.0
# 2020-05-30T02:28:33 INFO: Loading checkpoint
# [ Downloading: https://dl.fbaipublicfiles.com/mmf/data/models/mmbt/mmbt.finetuned.hateful_memes_images.tar.gz to /home/jupyter/.cache/torch/mmf/data/models/mmbt.hateful_memes.images/mmbt.finetuned.hateful_memes_images.tar.gz ]
# Downloading mmbt.finetuned.hateful_memes_images.tar.gz: 100%|█| 630M/630M [00:11
# [ Starting checksum for mmbt.finetuned.hateful_memes_images.tar.gz]
# [ Checksum successful for mmbt.finetuned.hateful_memes_images.tar.gz]
# Unpacking mmbt.finetuned.hateful_memes_images.tar.gz
# 2020-05-30T02:28:54 WARNING: /home/jupyter/mmf/mmf/utils/checkpoint.py:224: UserWarning: 'optimizer' key is not present in the checkpoint asked to be loaded. Skipping.
#   "'optimizer' key is not present in the "
#
# 2020-05-30T02:28:54 INFO: Checkpoint loaded
# 2020-05-30T02:28:54 INFO: Starting test inference predictions
# 2020-05-30T02:28:54 INFO: Predicting for hateful_memes
# 100%|███████████████████████████████████████████| 32/32 [08:07<00:00, 15.24s/it]
# 2020-05-30T02:37:02 INFO: Wrote evalai predictions for hateful_memes to /home/jupyter/meme_hateful_detection/notebooks/save/hateful_memes_mmbt_27132630/reports/hateful_memes_run_test_2020-05-30T02:37:02.csv
# 2020-05-30T02:37:02 INFO: Finished predicting
# Namespace(config_override=None, local_rank=None, opts=['config=configs/mmbt/with_features.yaml', 'model=mmbt', 'dataset=hateful_memes', 'run_type=test', 'checkpoint.resume_zoo=mmbt.hateful_memes.features', 'evaluation.predict=true'])
# /home/jupyter/mmf/mmf/utils/configuration.py:527: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   "Device specified is 'cuda' but cuda is not present. "
# Importing user_dir from /home/jupyter/meme_hateful_detection
# Overriding option config to configs/mmbt/with_features.yaml
# Overriding option model to mmbt
# Overriding option datasets to hateful_memes
# Overriding option run_type to test
# Overriding option checkpoint.resume_zoo to mmbt.hateful_memes.features
# Overriding option evaluation.predict to true
# Using seed 5713628
# Logging to: ./save/logs/train_2020-05-30T02:37:05.log
# 2020-05-30T02:37:05 INFO: Loading datasets
# 2020-05-30T02:37:10 INFO: Torch version is: 1.5.0
# 2020-05-30T02:37:10 INFO: Loading checkpoint
# [ Downloading: https://dl.fbaipublicfiles.com/mmf/data/models/mmbt/mmbt.finetuned.hateful_memes_features.tar.gz to /home/jupyter/.cache/torch/mmf/data/models/mmbt.hateful_memes.features/mmbt.finetuned.hateful_memes_features.tar.gz ]
# Downloading mmbt.finetuned.hateful_memes_features.tar.gz: 100%|█| 429M/429M [00:
# [ Starting checksum for mmbt.finetuned.hateful_memes_features.tar.gz]
# [ Checksum successful for mmbt.finetuned.hateful_memes_features.tar.gz]
# Unpacking mmbt.finetuned.hateful_memes_features.tar.gz
# 2020-05-30T02:37:31 WARNING: /home/jupyter/mmf/mmf/utils/checkpoint.py:224: UserWarning: 'optimizer' key is not present in the checkpoint asked to be loaded. Skipping.
#   "'optimizer' key is not present in the "
#
# 2020-05-30T02:37:31 INFO: Checkpoint loaded
# 2020-05-30T02:37:31 INFO: Starting test inference predictions
# 2020-05-30T02:37:31 INFO: Predicting for hateful_memes
# 100%|███████████████████████████████████████████| 32/32 [07:49<00:00, 14.66s/it]
# 2020-05-30T02:45:20 INFO: Wrote evalai predictions for hateful_memes to /home/jupyter/meme_hateful_detection/notebooks/save/hateful_memes_mmbt_5713628/reports/hateful_memes_run_test_2020-05-30T02:45:20.csv
# 2020-05-30T02:45:20 INFO: Finished predicting
# Namespace(config_override=None, local_rank=None, opts=['config=configs/vilbert/defaults.yaml', 'model=vilbert', 'dataset=hateful_memes', 'run_type=test', 'checkpoint.resume_zoo=vilbert.finetuned.hateful_memes.direct', 'evaluation.predict=true'])
# /home/jupyter/mmf/mmf/utils/configuration.py:527: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   "Device specified is 'cuda' but cuda is not present. "
# /opt/conda/lib/python3.7/site-packages/omegaconf/dictconfig.py:252: UserWarning: Keys with dot (model.bert) are deprecated and will have different semantic meaning the next major version of OmegaConf (2.1)
# See the compact keys issue for more details: https://github.com/omry/omegaconf/issues/152
# You can disable this warning by setting the environment variable OC_DISABLE_DOT_ACCESS_WARNING=1
#   warnings.warn(message=msg, category=UserWarning)
# Importing user_dir from /home/jupyter/meme_hateful_detection
# Overriding option config to configs/vilbert/defaults.yaml
# Overriding option model to vilbert
# Overriding option datasets to hateful_memes
# Overriding option run_type to test
# Overriding option checkpoint.resume_zoo to vilbert.finetuned.hateful_memes.direct
# Overriding option evaluation.predict to true
# Using seed 23832053
# Logging to: ./save/logs/train_2020-05-30T02:45:23.log
# 2020-05-30T02:45:23 INFO: Loading datasets
# 2020-05-30T02:45:29 INFO: Torch version is: 1.5.0
# 2020-05-30T02:45:29 INFO: Loading checkpoint
# [ Downloading: https://dl.fbaipublicfiles.com/mmf/data/models/vilbert/vilbert.finetuned.hateful_memes_direct.tar.gz to /home/jupyter/.cache/torch/mmf/data/models/vilbert.finetuned.hateful_memes.direct/vilbert.finetuned.hateful_memes_direct.tar.gz ]
# Downloading vilbert.finetuned.hateful_memes_direct.tar.gz: 100%|█| 918M/918M [00
# [ Starting checksum for vilbert.finetuned.hateful_memes_direct.tar.gz]
# [ Checksum successful for vilbert.finetuned.hateful_memes_direct.tar.gz]
# Unpacking vilbert.finetuned.hateful_memes_direct.tar.gz
# 2020-05-30T02:46:02 WARNING: /home/jupyter/mmf/mmf/utils/checkpoint.py:224: UserWarning: 'optimizer' key is not present in the checkpoint asked to be loaded. Skipping.
#   "'optimizer' key is not present in the "
#
# 2020-05-30T02:46:02 INFO: Checkpoint loaded
# 2020-05-30T02:46:02 INFO: Starting test inference predictions
# 2020-05-30T02:46:02 INFO: Predicting for hateful_memes
#   0%|                                                    | 0/32 [00:04<?, ?it/s]
# Traceback (most recent call last):
#   File "/opt/conda/bin/mmf_predict", line 11, in <module>
#     load_entry_point('mmf', 'console_scripts', 'mmf_predict')()
#   File "/home/jupyter/mmf/mmf_cli/predict.py", line 11, in predict
#     run(predict=True)
#   File "/home/jupyter/mmf/mmf_cli/run.py", line 89, in run
#     main(configuration, predict=predict)
#   File "/home/jupyter/mmf/mmf_cli/run.py", line 38, in main
#     trainer.inference()
#   File "/home/jupyter/mmf/mmf/trainers/base_trainer.py", line 490, in inference
#     self._inference_run("test")
#   File "/home/jupyter/mmf/mmf/trainers/base_trainer.py", line 494, in _inference_run
#     self.predict(dataset_type)
#   File "/home/jupyter/mmf/mmf/trainers/base_trainer.py", line 535, in predict
#     model_output = self.model(prepared_batch)
#   File "/home/jupyter/mmf/mmf/models/base_model.py", line 148, in __call__
#     model_output = super().__call__(sample_list, *args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py", line 550, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/home/jupyter/mmf/mmf/models/vilbert.py", line 1354, in forward
#     params = self.get_image_and_text_features(sample_list)
#   File "/home/jupyter/mmf/mmf/models/vilbert.py", line 1332, in get_image_and_text_features
#     image_location, dtype=torch.float
#   File "/opt/conda/lib/python3.7/site-packages/torch/cuda/__init__.py", line 149, in _lazy_init
#     _check_driver()
#   File "/opt/conda/lib/python3.7/site-packages/torch/cuda/__init__.py", line 54, in _check_driver
#     http://www.nvidia.com/Download/index.aspx""")
# AssertionError:
# Found no NVIDIA driver on your system. Please check that you
# have an NVIDIA GPU and installed a driver from
# http://www.nvidia.com/Download/index.aspx
# Namespace(config_override=None, local_rank=None, opts=['config=configs/visual_bert/direct.yaml', 'model=visual_bert', 'dataset=hateful_memes', 'run_type=test', 'checkpoint.resume_zoo=visual_bert.finetuned.hateful_memes.direct', 'evaluation.predict=true'])
# /home/jupyter/mmf/mmf/utils/configuration.py:527: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   "Device specified is 'cuda' but cuda is not present. "
# /opt/conda/lib/python3.7/site-packages/omegaconf/dictconfig.py:252: UserWarning: Keys with dot (model.bert) are deprecated and will have different semantic meaning the next major version of OmegaConf (2.1)
# See the compact keys issue for more details: https://github.com/omry/omegaconf/issues/152
# You can disable this warning by setting the environment variable OC_DISABLE_DOT_ACCESS_WARNING=1
#   warnings.warn(message=msg, category=UserWarning)
# Importing user_dir from /home/jupyter/meme_hateful_detection
# Overriding option config to configs/visual_bert/direct.yaml
# Overriding option model to visual_bert
# Overriding option datasets to hateful_memes
# Overriding option run_type to test
# Overriding option checkpoint.resume_zoo to visual_bert.finetuned.hateful_memes.direct
# Overriding option evaluation.predict to true
# Using seed 9907870
# Logging to: ./save/logs/train_2020-05-30T02:46:09.log
# 2020-05-30T02:46:09 INFO: Loading datasets
# 2020-05-30T02:46:14 INFO: Torch version is: 1.5.0
# 2020-05-30T02:46:14 INFO: Loading checkpoint
# [ Downloading: https://dl.fbaipublicfiles.com/mmf/data/models/visual_bert/visual_bert.finetuned.hateful_memes_direct.tar.gz to /home/jupyter/.cache/torch/mmf/data/models/visual_bert.finetuned.hateful_memes.direct/visual_bert.finetuned.hateful_memes_direct.tar.gz ]
# Downloading visual_bert.finetuned.hateful_memes_direct.tar.gz: 100%|█| 415M/415M
# [ Starting checksum for visual_bert.finetuned.hateful_memes_direct.tar.gz]
# [ Checksum successful for visual_bert.finetuned.hateful_memes_direct.tar.gz]
# Unpacking visual_bert.finetuned.hateful_memes_direct.tar.gz
# 2020-05-30T02:46:28 WARNING: /home/jupyter/mmf/mmf/utils/checkpoint.py:224: UserWarning: 'optimizer' key is not present in the checkpoint asked to be loaded. Skipping.
#   "'optimizer' key is not present in the "
#
# 2020-05-30T02:46:28 INFO: Checkpoint loaded
# 2020-05-30T02:46:28 INFO: Starting test inference predictions
# 2020-05-30T02:46:28 INFO: Predicting for hateful_memes
#   0%|                                                     | 0/8 [00:02<?, ?it/s]
# Traceback (most recent call last):
#   File "/opt/conda/bin/mmf_predict", line 11, in <module>
#     load_entry_point('mmf', 'console_scripts', 'mmf_predict')()
#   File "/home/jupyter/mmf/mmf_cli/predict.py", line 11, in predict
#     run(predict=True)
#   File "/home/jupyter/mmf/mmf_cli/run.py", line 89, in run
#     main(configuration, predict=predict)
#   File "/home/jupyter/mmf/mmf_cli/run.py", line 38, in main
#     trainer.inference()
#   File "/home/jupyter/mmf/mmf/trainers/base_trainer.py", line 490, in inference
#     self._inference_run("test")
#   File "/home/jupyter/mmf/mmf/trainers/base_trainer.py", line 494, in _inference_run
#     self.predict(dataset_type)
#   File "/home/jupyter/mmf/mmf/trainers/base_trainer.py", line 535, in predict
#     model_output = self.model(prepared_batch)
#   File "/home/jupyter/mmf/mmf/models/base_model.py", line 148, in __call__
#     model_output = super().__call__(sample_list, *args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py", line 550, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/home/jupyter/mmf/mmf/models/visual_bert.py", line 525, in forward
#     sample_list = self.add_custom_params(sample_list)
#   File "/home/jupyter/mmf/mmf/models/visual_bert.py", line 499, in add_custom_params
#     .expand(*visual_embeddings.size()[:-1])
#   File "/opt/conda/lib/python3.7/site-packages/torch/cuda/__init__.py", line 149, in _lazy_init
#     _check_driver()
#   File "/opt/conda/lib/python3.7/site-packages/torch/cuda/__init__.py", line 54, in _check_driver
#     http://www.nvidia.com/Download/index.aspx""")
# AssertionError:
# Found no NVIDIA driver on your system. Please check that you
# have an NVIDIA GPU and installed a driver from
# http://www.nvidia.com/Download/index.aspx
# Namespace(config_override=None, local_rank=None, opts=['config=configs/vilbert/from_cc.yaml', 'model=vilbert', 'dataset=hateful_memes', 'run_type=test', 'checkpoint.resume_zoo=vilbert.finetuned.hateful_memes.from_cc_original', 'evaluation.predict=true'])
# /home/jupyter/mmf/mmf/utils/configuration.py:527: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   "Device specified is 'cuda' but cuda is not present. "
# /opt/conda/lib/python3.7/site-packages/omegaconf/dictconfig.py:252: UserWarning: Keys with dot (model.bert) are deprecated and will have different semantic meaning the next major version of OmegaConf (2.1)
# See the compact keys issue for more details: https://github.com/omry/omegaconf/issues/152
# You can disable this warning by setting the environment variable OC_DISABLE_DOT_ACCESS_WARNING=1
#   warnings.warn(message=msg, category=UserWarning)
# Importing user_dir from /home/jupyter/meme_hateful_detection
# Overriding option config to configs/vilbert/from_cc.yaml
# Overriding option model to vilbert
# Overriding option datasets to hateful_memes
# Overriding option run_type to test
# Overriding option checkpoint.resume_zoo to vilbert.finetuned.hateful_memes.from_cc_original
# Overriding option evaluation.predict to true
# Using seed 37549693
# Logging to: ./save/logs/train_2020-05-30T02:46:37.log
# 2020-05-30T02:46:37 INFO: Loading datasets
# 2020-05-30T02:46:50 INFO: Torch version is: 1.5.0
# 2020-05-30T02:46:50 INFO: Loading checkpoint
# [ Downloading: https://dl.fbaipublicfiles.com/mmf/data/models/vilbert/vilbert.finetuned.hateful_memes_from_cc.tar.gz to /home/jupyter/.cache/torch/mmf/data/models/vilbert.finetuned.hateful_memes.from_cc_original/vilbert.finetuned.hateful_memes_from_cc.tar.gz ]
# Downloading vilbert.finetuned.hateful_memes_from_cc.tar.gz: 100%|█| 918M/918M [0
# [ Starting checksum for vilbert.finetuned.hateful_memes_from_cc.tar.gz]
# [ Checksum successful for vilbert.finetuned.hateful_memes_from_cc.tar.gz]
# Unpacking vilbert.finetuned.hateful_memes_from_cc.tar.gz
# 2020-05-30T02:47:20 INFO: Copying model.bert.embeddings.word_embeddings.weight from model.bert.embeddings.word_embeddings.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.embeddings.position_embeddings.weight from model.bert.embeddings.position_embeddings.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.embeddings.token_type_embeddings.weight from model.bert.embeddings.token_type_embeddings.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.embeddings.LayerNorm.weight from model.bert.embeddings.LayerNorm.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.embeddings.LayerNorm.bias from model.bert.embeddings.LayerNorm.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.v_embeddings.image_embeddings.weight from model.bert.v_embeddings.image_embeddings.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.v_embeddings.image_embeddings.bias from model.bert.v_embeddings.image_embeddings.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.v_embeddings.image_location_embeddings.weight from model.bert.v_embeddings.image_location_embeddings.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.v_embeddings.image_location_embeddings.bias from model.bert.v_embeddings.image_location_embeddings.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.v_embeddings.LayerNorm.weight from model.bert.v_embeddings.LayerNorm.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.v_embeddings.LayerNorm.bias from model.bert.v_embeddings.LayerNorm.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.0.attention.self.query.weight from model.bert.encoder.layer.0.attention.self.query.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.0.attention.self.query.bias from model.bert.encoder.layer.0.attention.self.query.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.0.attention.self.key.weight from model.bert.encoder.layer.0.attention.self.key.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.0.attention.self.key.bias from model.bert.encoder.layer.0.attention.self.key.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.0.attention.self.value.weight from model.bert.encoder.layer.0.attention.self.value.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.0.attention.self.value.bias from model.bert.encoder.layer.0.attention.self.value.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.0.attention.output.dense.weight from model.bert.encoder.layer.0.attention.output.dense.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.0.attention.output.dense.bias from model.bert.encoder.layer.0.attention.output.dense.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.0.attention.output.LayerNorm.weight from model.bert.encoder.layer.0.attention.output.LayerNorm.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.0.attention.output.LayerNorm.bias from model.bert.encoder.layer.0.attention.output.LayerNorm.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.0.intermediate.dense.weight from model.bert.encoder.layer.0.intermediate.dense.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.0.intermediate.dense.bias from model.bert.encoder.layer.0.intermediate.dense.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.0.output.dense.weight from model.bert.encoder.layer.0.output.dense.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.0.output.dense.bias from model.bert.encoder.layer.0.output.dense.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.0.output.LayerNorm.weight from model.bert.encoder.layer.0.output.LayerNorm.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.0.output.LayerNorm.bias from model.bert.encoder.layer.0.output.LayerNorm.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.1.attention.self.query.weight from model.bert.encoder.layer.1.attention.self.query.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.1.attention.self.query.bias from model.bert.encoder.layer.1.attention.self.query.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.1.attention.self.key.weight from model.bert.encoder.layer.1.attention.self.key.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.1.attention.self.key.bias from model.bert.encoder.layer.1.attention.self.key.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.1.attention.self.value.weight from model.bert.encoder.layer.1.attention.self.value.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.1.attention.self.value.bias from model.bert.encoder.layer.1.attention.self.value.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.1.attention.output.dense.weight from model.bert.encoder.layer.1.attention.output.dense.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.1.attention.output.dense.bias from model.bert.encoder.layer.1.attention.output.dense.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.1.attention.output.LayerNorm.weight from model.bert.encoder.layer.1.attention.output.LayerNorm.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.1.attention.output.LayerNorm.bias from model.bert.encoder.layer.1.attention.output.LayerNorm.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.1.intermediate.dense.weight from model.bert.encoder.layer.1.intermediate.dense.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.1.intermediate.dense.bias from model.bert.encoder.layer.1.intermediate.dense.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.1.output.dense.weight from model.bert.encoder.layer.1.output.dense.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.1.output.dense.bias from model.bert.encoder.layer.1.output.dense.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.1.output.LayerNorm.weight from model.bert.encoder.layer.1.output.LayerNorm.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.1.output.LayerNorm.bias from model.bert.encoder.layer.1.output.LayerNorm.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.2.attention.self.query.weight from model.bert.encoder.layer.2.attention.self.query.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.2.attention.self.query.bias from model.bert.encoder.layer.2.attention.self.query.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.2.attention.self.key.weight from model.bert.encoder.layer.2.attention.self.key.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.2.attention.self.key.bias from model.bert.encoder.layer.2.attention.self.key.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.2.attention.self.value.weight from model.bert.encoder.layer.2.attention.self.value.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.2.attention.self.value.bias from model.bert.encoder.layer.2.attention.self.value.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.2.attention.output.dense.weight from model.bert.encoder.layer.2.attention.output.dense.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.2.attention.output.dense.bias from model.bert.encoder.layer.2.attention.output.dense.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.2.attention.output.LayerNorm.weight from model.bert.encoder.layer.2.attention.output.LayerNorm.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.2.attention.output.LayerNorm.bias from model.bert.encoder.layer.2.attention.output.LayerNorm.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.2.intermediate.dense.weight from model.bert.encoder.layer.2.intermediate.dense.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.2.intermediate.dense.bias from model.bert.encoder.layer.2.intermediate.dense.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.2.output.dense.weight from model.bert.encoder.layer.2.output.dense.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.2.output.dense.bias from model.bert.encoder.layer.2.output.dense.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.2.output.LayerNorm.weight from model.bert.encoder.layer.2.output.LayerNorm.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.2.output.LayerNorm.bias from model.bert.encoder.layer.2.output.LayerNorm.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.3.attention.self.query.weight from model.bert.encoder.layer.3.attention.self.query.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.3.attention.self.query.bias from model.bert.encoder.layer.3.attention.self.query.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.3.attention.self.key.weight from model.bert.encoder.layer.3.attention.self.key.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.3.attention.self.key.bias from model.bert.encoder.layer.3.attention.self.key.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.3.attention.self.value.weight from model.bert.encoder.layer.3.attention.self.value.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.3.attention.self.value.bias from model.bert.encoder.layer.3.attention.self.value.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.3.attention.output.dense.weight from model.bert.encoder.layer.3.attention.output.dense.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.3.attention.output.dense.bias from model.bert.encoder.layer.3.attention.output.dense.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.3.attention.output.LayerNorm.weight from model.bert.encoder.layer.3.attention.output.LayerNorm.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.3.attention.output.LayerNorm.bias from model.bert.encoder.layer.3.attention.output.LayerNorm.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.3.intermediate.dense.weight from model.bert.encoder.layer.3.intermediate.dense.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.3.intermediate.dense.bias from model.bert.encoder.layer.3.intermediate.dense.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.3.output.dense.weight from model.bert.encoder.layer.3.output.dense.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.3.output.dense.bias from model.bert.encoder.layer.3.output.dense.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.3.output.LayerNorm.weight from model.bert.encoder.layer.3.output.LayerNorm.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.3.output.LayerNorm.bias from model.bert.encoder.layer.3.output.LayerNorm.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.4.attention.self.query.weight from model.bert.encoder.layer.4.attention.self.query.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.4.attention.self.query.bias from model.bert.encoder.layer.4.attention.self.query.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.4.attention.self.key.weight from model.bert.encoder.layer.4.attention.self.key.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.4.attention.self.key.bias from model.bert.encoder.layer.4.attention.self.key.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.4.attention.self.value.weight from model.bert.encoder.layer.4.attention.self.value.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.4.attention.self.value.bias from model.bert.encoder.layer.4.attention.self.value.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.4.attention.output.dense.weight from model.bert.encoder.layer.4.attention.output.dense.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.4.attention.output.dense.bias from model.bert.encoder.layer.4.attention.output.dense.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.4.attention.output.LayerNorm.weight from model.bert.encoder.layer.4.attention.output.LayerNorm.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.4.attention.output.LayerNorm.bias from model.bert.encoder.layer.4.attention.output.LayerNorm.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.4.intermediate.dense.weight from model.bert.encoder.layer.4.intermediate.dense.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.4.intermediate.dense.bias from model.bert.encoder.layer.4.intermediate.dense.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.4.output.dense.weight from model.bert.encoder.layer.4.output.dense.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.4.output.dense.bias from model.bert.encoder.layer.4.output.dense.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.4.output.LayerNorm.weight from model.bert.encoder.layer.4.output.LayerNorm.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.4.output.LayerNorm.bias from model.bert.encoder.layer.4.output.LayerNorm.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.5.attention.self.query.weight from model.bert.encoder.layer.5.attention.self.query.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.5.attention.self.query.bias from model.bert.encoder.layer.5.attention.self.query.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.5.attention.self.key.weight from model.bert.encoder.layer.5.attention.self.key.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.5.attention.self.key.bias from model.bert.encoder.layer.5.attention.self.key.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.5.attention.self.value.weight from model.bert.encoder.layer.5.attention.self.value.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.5.attention.self.value.bias from model.bert.encoder.layer.5.attention.self.value.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.5.attention.output.dense.weight from model.bert.encoder.layer.5.attention.output.dense.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.5.attention.output.dense.bias from model.bert.encoder.layer.5.attention.output.dense.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.5.attention.output.LayerNorm.weight from model.bert.encoder.layer.5.attention.output.LayerNorm.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.5.attention.output.LayerNorm.bias from model.bert.encoder.layer.5.attention.output.LayerNorm.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.5.intermediate.dense.weight from model.bert.encoder.layer.5.intermediate.dense.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.5.intermediate.dense.bias from model.bert.encoder.layer.5.intermediate.dense.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.5.output.dense.weight from model.bert.encoder.layer.5.output.dense.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.5.output.dense.bias from model.bert.encoder.layer.5.output.dense.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.5.output.LayerNorm.weight from model.bert.encoder.layer.5.output.LayerNorm.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.5.output.LayerNorm.bias from model.bert.encoder.layer.5.output.LayerNorm.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.6.attention.self.query.weight from model.bert.encoder.layer.6.attention.self.query.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.6.attention.self.query.bias from model.bert.encoder.layer.6.attention.self.query.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.6.attention.self.key.weight from model.bert.encoder.layer.6.attention.self.key.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.6.attention.self.key.bias from model.bert.encoder.layer.6.attention.self.key.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.6.attention.self.value.weight from model.bert.encoder.layer.6.attention.self.value.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.6.attention.self.value.bias from model.bert.encoder.layer.6.attention.self.value.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.6.attention.output.dense.weight from model.bert.encoder.layer.6.attention.output.dense.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.6.attention.output.dense.bias from model.bert.encoder.layer.6.attention.output.dense.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.6.attention.output.LayerNorm.weight from model.bert.encoder.layer.6.attention.output.LayerNorm.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.6.attention.output.LayerNorm.bias from model.bert.encoder.layer.6.attention.output.LayerNorm.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.6.intermediate.dense.weight from model.bert.encoder.layer.6.intermediate.dense.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.6.intermediate.dense.bias from model.bert.encoder.layer.6.intermediate.dense.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.6.output.dense.weight from model.bert.encoder.layer.6.output.dense.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.6.output.dense.bias from model.bert.encoder.layer.6.output.dense.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.6.output.LayerNorm.weight from model.bert.encoder.layer.6.output.LayerNorm.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.6.output.LayerNorm.bias from model.bert.encoder.layer.6.output.LayerNorm.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.7.attention.self.query.weight from model.bert.encoder.layer.7.attention.self.query.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.7.attention.self.query.bias from model.bert.encoder.layer.7.attention.self.query.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.7.attention.self.key.weight from model.bert.encoder.layer.7.attention.self.key.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.7.attention.self.key.bias from model.bert.encoder.layer.7.attention.self.key.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.7.attention.self.value.weight from model.bert.encoder.layer.7.attention.self.value.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.7.attention.self.value.bias from model.bert.encoder.layer.7.attention.self.value.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.7.attention.output.dense.weight from model.bert.encoder.layer.7.attention.output.dense.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.7.attention.output.dense.bias from model.bert.encoder.layer.7.attention.output.dense.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.7.attention.output.LayerNorm.weight from model.bert.encoder.layer.7.attention.output.LayerNorm.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.7.attention.output.LayerNorm.bias from model.bert.encoder.layer.7.attention.output.LayerNorm.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.7.intermediate.dense.weight from model.bert.encoder.layer.7.intermediate.dense.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.7.intermediate.dense.bias from model.bert.encoder.layer.7.intermediate.dense.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.7.output.dense.weight from model.bert.encoder.layer.7.output.dense.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.7.output.dense.bias from model.bert.encoder.layer.7.output.dense.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.7.output.LayerNorm.weight from model.bert.encoder.layer.7.output.LayerNorm.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.7.output.LayerNorm.bias from model.bert.encoder.layer.7.output.LayerNorm.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.8.attention.self.query.weight from model.bert.encoder.layer.8.attention.self.query.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.8.attention.self.query.bias from model.bert.encoder.layer.8.attention.self.query.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.8.attention.self.key.weight from model.bert.encoder.layer.8.attention.self.key.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.8.attention.self.key.bias from model.bert.encoder.layer.8.attention.self.key.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.8.attention.self.value.weight from model.bert.encoder.layer.8.attention.self.value.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.8.attention.self.value.bias from model.bert.encoder.layer.8.attention.self.value.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.8.attention.output.dense.weight from model.bert.encoder.layer.8.attention.output.dense.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.8.attention.output.dense.bias from model.bert.encoder.layer.8.attention.output.dense.bias
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.8.attention.output.LayerNorm.weight from model.bert.encoder.layer.8.attention.output.LayerNorm.weight
# 2020-05-30T02:47:20 INFO: Copying model.bert.encoder.layer.8.attention.output.LayerNorm.bias from model.bert.encoder.layer.8.attention.output.LayerNorm.bias
# ...
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.6.attention.self.key.weight from model.bert.encoder.layer.6.attention.self.key.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.6.attention.self.key.bias from model.bert.encoder.layer.6.attention.self.key.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.6.attention.self.value.weight from model.bert.encoder.layer.6.attention.self.value.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.6.attention.self.value.bias from model.bert.encoder.layer.6.attention.self.value.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.6.attention.output.dense.weight from model.bert.encoder.layer.6.attention.output.dense.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.6.attention.output.dense.bias from model.bert.encoder.layer.6.attention.output.dense.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.6.attention.output.LayerNorm.weight from model.bert.encoder.layer.6.attention.output.LayerNorm.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.6.attention.output.LayerNorm.bias from model.bert.encoder.layer.6.attention.output.LayerNorm.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.6.intermediate.dense.weight from model.bert.encoder.layer.6.intermediate.dense.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.6.intermediate.dense.bias from model.bert.encoder.layer.6.intermediate.dense.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.6.output.dense.weight from model.bert.encoder.layer.6.output.dense.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.6.output.dense.bias from model.bert.encoder.layer.6.output.dense.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.6.output.LayerNorm.weight from model.bert.encoder.layer.6.output.LayerNorm.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.6.output.LayerNorm.bias from model.bert.encoder.layer.6.output.LayerNorm.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.7.attention.self.query.weight from model.bert.encoder.layer.7.attention.self.query.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.7.attention.self.query.bias from model.bert.encoder.layer.7.attention.self.query.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.7.attention.self.key.weight from model.bert.encoder.layer.7.attention.self.key.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.7.attention.self.key.bias from model.bert.encoder.layer.7.attention.self.key.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.7.attention.self.value.weight from model.bert.encoder.layer.7.attention.self.value.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.7.attention.self.value.bias from model.bert.encoder.layer.7.attention.self.value.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.7.attention.output.dense.weight from model.bert.encoder.layer.7.attention.output.dense.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.7.attention.output.dense.bias from model.bert.encoder.layer.7.attention.output.dense.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.7.attention.output.LayerNorm.weight from model.bert.encoder.layer.7.attention.output.LayerNorm.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.7.attention.output.LayerNorm.bias from model.bert.encoder.layer.7.attention.output.LayerNorm.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.7.intermediate.dense.weight from model.bert.encoder.layer.7.intermediate.dense.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.7.intermediate.dense.bias from model.bert.encoder.layer.7.intermediate.dense.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.7.output.dense.weight from model.bert.encoder.layer.7.output.dense.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.7.output.dense.bias from model.bert.encoder.layer.7.output.dense.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.7.output.LayerNorm.weight from model.bert.encoder.layer.7.output.LayerNorm.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.7.output.LayerNorm.bias from model.bert.encoder.layer.7.output.LayerNorm.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.8.attention.self.query.weight from model.bert.encoder.layer.8.attention.self.query.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.8.attention.self.query.bias from model.bert.encoder.layer.8.attention.self.query.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.8.attention.self.key.weight from model.bert.encoder.layer.8.attention.self.key.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.8.attention.self.key.bias from model.bert.encoder.layer.8.attention.self.key.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.8.attention.self.value.weight from model.bert.encoder.layer.8.attention.self.value.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.8.attention.self.value.bias from model.bert.encoder.layer.8.attention.self.value.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.8.attention.output.dense.weight from model.bert.encoder.layer.8.attention.output.dense.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.8.attention.output.dense.bias from model.bert.encoder.layer.8.attention.output.dense.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.8.attention.output.LayerNorm.weight from model.bert.encoder.layer.8.attention.output.LayerNorm.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.8.attention.output.LayerNorm.bias from model.bert.encoder.layer.8.attention.output.LayerNorm.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.8.intermediate.dense.weight from model.bert.encoder.layer.8.intermediate.dense.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.8.intermediate.dense.bias from model.bert.encoder.layer.8.intermediate.dense.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.8.output.dense.weight from model.bert.encoder.layer.8.output.dense.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.8.output.dense.bias from model.bert.encoder.layer.8.output.dense.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.8.output.LayerNorm.weight from model.bert.encoder.layer.8.output.LayerNorm.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.8.output.LayerNorm.bias from model.bert.encoder.layer.8.output.LayerNorm.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.9.attention.self.query.weight from model.bert.encoder.layer.9.attention.self.query.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.9.attention.self.query.bias from model.bert.encoder.layer.9.attention.self.query.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.9.attention.self.key.weight from model.bert.encoder.layer.9.attention.self.key.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.9.attention.self.key.bias from model.bert.encoder.layer.9.attention.self.key.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.9.attention.self.value.weight from model.bert.encoder.layer.9.attention.self.value.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.9.attention.self.value.bias from model.bert.encoder.layer.9.attention.self.value.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.9.attention.output.dense.weight from model.bert.encoder.layer.9.attention.output.dense.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.9.attention.output.dense.bias from model.bert.encoder.layer.9.attention.output.dense.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.9.attention.output.LayerNorm.weight from model.bert.encoder.layer.9.attention.output.LayerNorm.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.9.attention.output.LayerNorm.bias from model.bert.encoder.layer.9.attention.output.LayerNorm.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.9.intermediate.dense.weight from model.bert.encoder.layer.9.intermediate.dense.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.9.intermediate.dense.bias from model.bert.encoder.layer.9.intermediate.dense.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.9.output.dense.weight from model.bert.encoder.layer.9.output.dense.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.9.output.dense.bias from model.bert.encoder.layer.9.output.dense.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.9.output.LayerNorm.weight from model.bert.encoder.layer.9.output.LayerNorm.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.9.output.LayerNorm.bias from model.bert.encoder.layer.9.output.LayerNorm.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.10.attention.self.query.weight from model.bert.encoder.layer.10.attention.self.query.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.10.attention.self.query.bias from model.bert.encoder.layer.10.attention.self.query.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.10.attention.self.key.weight from model.bert.encoder.layer.10.attention.self.key.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.10.attention.self.key.bias from model.bert.encoder.layer.10.attention.self.key.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.10.attention.self.value.weight from model.bert.encoder.layer.10.attention.self.value.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.10.attention.self.value.bias from model.bert.encoder.layer.10.attention.self.value.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.10.attention.output.dense.weight from model.bert.encoder.layer.10.attention.output.dense.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.10.attention.output.dense.bias from model.bert.encoder.layer.10.attention.output.dense.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.10.attention.output.LayerNorm.weight from model.bert.encoder.layer.10.attention.output.LayerNorm.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.10.attention.output.LayerNorm.bias from model.bert.encoder.layer.10.attention.output.LayerNorm.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.10.intermediate.dense.weight from model.bert.encoder.layer.10.intermediate.dense.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.10.intermediate.dense.bias from model.bert.encoder.layer.10.intermediate.dense.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.10.output.dense.weight from model.bert.encoder.layer.10.output.dense.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.10.output.dense.bias from model.bert.encoder.layer.10.output.dense.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.10.output.LayerNorm.weight from model.bert.encoder.layer.10.output.LayerNorm.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.10.output.LayerNorm.bias from model.bert.encoder.layer.10.output.LayerNorm.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.11.attention.self.query.weight from model.bert.encoder.layer.11.attention.self.query.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.11.attention.self.query.bias from model.bert.encoder.layer.11.attention.self.query.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.11.attention.self.key.weight from model.bert.encoder.layer.11.attention.self.key.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.11.attention.self.key.bias from model.bert.encoder.layer.11.attention.self.key.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.11.attention.self.value.weight from model.bert.encoder.layer.11.attention.self.value.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.11.attention.self.value.bias from model.bert.encoder.layer.11.attention.self.value.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.11.attention.output.dense.weight from model.bert.encoder.layer.11.attention.output.dense.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.11.attention.output.dense.bias from model.bert.encoder.layer.11.attention.output.dense.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.11.attention.output.LayerNorm.weight from model.bert.encoder.layer.11.attention.output.LayerNorm.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.11.attention.output.LayerNorm.bias from model.bert.encoder.layer.11.attention.output.LayerNorm.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.11.intermediate.dense.weight from model.bert.encoder.layer.11.intermediate.dense.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.11.intermediate.dense.bias from model.bert.encoder.layer.11.intermediate.dense.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.11.output.dense.weight from model.bert.encoder.layer.11.output.dense.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.11.output.dense.bias from model.bert.encoder.layer.11.output.dense.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.11.output.LayerNorm.weight from model.bert.encoder.layer.11.output.LayerNorm.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.encoder.layer.11.output.LayerNorm.bias from model.bert.encoder.layer.11.output.LayerNorm.bias
# 2020-05-30T02:49:18 INFO: Copying model.bert.pooler.dense.weight from model.bert.pooler.dense.weight
# 2020-05-30T02:49:18 INFO: Copying model.bert.pooler.dense.bias from model.bert.pooler.dense.bias
# 2020-05-30T02:49:18 INFO: Pretrained model loaded
# 2020-05-30T02:49:18 INFO: Starting test inference predictions
# 2020-05-30T02:49:18 INFO: Predicting for hateful_memes
#   0%|                                                    | 0/16 [00:01<?, ?it/s]
# Traceback (most recent call last):
#   File "/opt/conda/bin/mmf_predict", line 11, in <module>
#     load_entry_point('mmf', 'console_scripts', 'mmf_predict')()
#   File "/home/jupyter/mmf/mmf_cli/predict.py", line 11, in predict
#     run(predict=True)
#   File "/home/jupyter/mmf/mmf_cli/run.py", line 89, in run
#     main(configuration, predict=predict)
#   File "/home/jupyter/mmf/mmf_cli/run.py", line 38, in main
#     trainer.inference()
#   File "/home/jupyter/mmf/mmf/trainers/base_trainer.py", line 490, in inference
#     self._inference_run("test")
#   File "/home/jupyter/mmf/mmf/trainers/base_trainer.py", line 494, in _inference_run
#     self.predict(dataset_type)
#   File "/home/jupyter/mmf/mmf/trainers/base_trainer.py", line 535, in predict
#     model_output = self.model(prepared_batch)
#   File "/home/jupyter/mmf/mmf/models/base_model.py", line 148, in __call__
#     model_output = super().__call__(sample_list, *args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py", line 550, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/home/jupyter/mmf/mmf/models/visual_bert.py", line 525, in forward
#     sample_list = self.add_custom_params(sample_list)
#   File "/home/jupyter/mmf/mmf/models/visual_bert.py", line 499, in add_custom_params
#     .expand(*visual_embeddings.size()[:-1])
#   File "/opt/conda/lib/python3.7/site-packages/torch/cuda/__init__.py", line 149, in _lazy_init
#     _check_driver()
#   File "/opt/conda/lib/python3.7/site-packages/torch/cuda/__init__.py", line 54, in _check_driver
#     http://www.nvidia.com/Download/index.aspx""")
# AssertionError:
# Found no NVIDIA driver on your system. Please check that you
# have an NVIDIA GPU and installed a driver from
# http://www.nvidia.com/Download/index.aspx

# %%
from mmf.common.registry import registry

model_cls = registry.get_model_class("unimodal_image")
model = model_cls.from_pretrained("unimodal_image.hateful_memes.images")

# %%
# Training
# !mmf_run config=projects/hateful_memes/configs/unimodal/image.yaml model=unimodal_image dataset=hateful_memes

# %%
# Evaluation
# !mmf_run config=projects/hateful_memes/configs/unimodal/image.yaml model=unimodal_image dataset=hateful_memes run_type=val

# %%
# Predictions
#Val
# !mmf_predict config=projects/hateful_memes/configs/unimodal/image.yaml model=unimodal_image dataset=hateful_memes run_type=val

#Test
# !mmf_predict config=projects/hateful_memes/configs/mmbt/defaults.yaml model=mmbt dataset=hateful_memes run_type=test

# %%
from mmf.common.registry import registry


import torch
import torch.nn as nn
from torch.autograd import Variable

# # Defining Model
# class LinearRegressor(nn.Module):
#     def __init__(self, inp_size, require_bias=True):
#         super(LinearRegressor, self).__init__()
#         self.linear = nn.Linear(in_features=inp_size, out_features=1, bias=require_bias)
    
#     def forward(self, inp_batch):
#         return self.linear(inp_batch)
    
# Creating sample data for sum of 3 elements
X = []
for i in range(2):
    for j in range(2):
        for k in range(2):
            X.append([i, j, k])

y = map(lambda x: x[0] + x[1] + x[2], X)
X = Variable(torch.FloatTensor(X), requires_grad=False)
y = Variable(torch.FloatTensor(y), requires_grad=False)

# Creating model and defining loss function and optimizer
model_cls = registry.get_model_class("unimodal_image")
model = model_cls.from_pretrained("unimodal_image.hateful_memes.images")
loss_fn = nn.MSELoss()
optim = torch.optim.Adam(model.parameters())

# Training the model
for epoch in range(2):
    optim.zero_grad()
    
    out = model(X)
    loss = loss_fn(out, y)
    
    loss.backward()
    optim.step()
